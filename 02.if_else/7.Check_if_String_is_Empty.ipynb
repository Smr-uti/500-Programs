# %% [markdown]
# #### 7. Check if String is Empty:Check if the user typed something or just pressed enter without typing.

# %%
text=input("Enter something:")

if text != "":
    print("You Entered:", text)
else:
    print("You didn't enter anything")
# Out:
# You didn't enter anything
