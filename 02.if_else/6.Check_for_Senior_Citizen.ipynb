# %% [markdown]
# #### 3. Check for Senior Citizen: If the age is 60 or above, display "Senior Citizen", otherwise display "General Category".

# %%
age=int(input("Enter the age:"))
print(age)

if age>60:
    print("Senior Citizen")
else:
    print("General Category")
# Out:
# 50
# General Category
