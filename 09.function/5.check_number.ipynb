# %% [markdown]
# #### Write a Python program using a function to check whether a given number is Positive, Negative, or Zero.

# %%
def check_number(num1):
    if num1 > 0:
        return "Positive"
    elif num1 < 0:
        return "Negative"
    else: 
        number = 0
        return "Zero"

number = -15
result = check_number(number)

print(result)
# Out:
# Negative
