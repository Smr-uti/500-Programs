# %% [markdown]
# #### 1. Addition Function

# %%
def add(a, b):
     return a + b
a= 10
b= 20
   
result= add(a, b)

print(result)
# Out:
# 30

# %% [markdown]
# #### 2. Square

# %%
def square(num1):
    return num1 * num1
number = 25

result = square(number)

print(result)
# Out:
# 625
