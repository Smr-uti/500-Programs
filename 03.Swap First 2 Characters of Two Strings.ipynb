# %% [markdown]
# ## Swap First 2 Characters of Two Strings
#
# #### Problem Statement:
# ##### Write a Python function to create a single string from two given strings, separated by a space, where the first two characters of each string are swapped.
