# %% [markdown]
# #### 1. Positive Number:- Write a Python program to check whether a given number is positive.

# %%
number=int(input("Enter a number:"))
print(number)
if number>0:
    print("Number is Positive")
# Out:
# 79
# Number is Positive

# %%
number = int(input("Enter a number:"))
print(number)
if number>0:
    print("Number is positive")
# Out:
# 75
# Number is positive

# %%
num1 = int(input("Enter the number:"))
print(num1)
if num1 > 0:
    print("It is Positive")
