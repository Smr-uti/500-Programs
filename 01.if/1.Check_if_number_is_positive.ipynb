# %% [markdown]
# #### Check if a Number is Positive:The user for a number and print a message only if it is greater than 0.

# %%
number=int(input("Enter a number:"))
print(number)
if number>0:
    print("Number is Positive")
# Out:
# 40
# Number is Positive
