# %% [markdown]
# #### Write a Python program to check whether the temperature is above 30°C

# %%
temprature = 35 
if temprature > 30:
    print(temprature)
    print("It is hot day")
# Out:
# 35
# It is hot day
