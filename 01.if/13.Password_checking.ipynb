# %% [markdown]
# #### Write a Python program to check whether a given password is correct

# %%
password = "python123"
if password == "python123":
    print("Correct Password")
# Out:
# Correct Password
