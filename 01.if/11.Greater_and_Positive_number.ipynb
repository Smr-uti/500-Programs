# %% [markdown]
# #### Write a Python program to check whether a given number is positive and greater than 50.

# %%
number = 75
if number > 0 and number > 50:
    print(number)
    print("Number is Positive and Greater than 50")
# Out:
# number
# Number is Positive and Greater than 50
