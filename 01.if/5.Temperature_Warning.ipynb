# %% [markdown]
# ##### 5. Temperature Warning:If the temperature goes above 40 degrees, print a warning message.

# %%
temp=int(input("Enter the temprature"))
print("temp")

if temp>40:
    print("Warning: It is extremely hot outside! Stay indoors.")
# Out:
# temp
# ...
