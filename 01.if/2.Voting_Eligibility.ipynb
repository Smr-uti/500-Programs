# %% [markdown]
# #### 2. Voting Eligibility: Check if the user's age is 18 or older. If yes, print that they can vote.

# %%
age=int(input("Enter the Age:"))
print(age)
if age>=18:
    print("You are Eligible for Voting")
# Out:
# 18
# You are Eligible for Voting
