# %% [markdown]
# #### 3. Greater Number:- Write a Python program to check whether the first number is greater than the second number.

# %%
number1 = 10
number2 = 5

if number1 > number2:
    print(number1)
    print(number2)
    print("Number1 is greater than number2")
# Out:
# 10
# 5
# Number1 is greater than number2

# %% [markdown]
# #### Write a Python program to check whether a student has scored more than 75 marks.

# %%
marks = 82
if marks > 75:
    print("Excellent")
# Out:
# Excellent

# %% [markdown]
# #### Write a Python program to check whether a customer has a high electricity bill.

# %%
electricity_bill = 4500
if electricity_bill > 3000:
    print("Higher Electricity Bill")
# Out:
# Higher Electricity Bill
