# %% [markdown]
# #### 5. Divisible by 3 and 5:- Write a Python program to check whether a given number is divisible by both 3 and 5

# %%
number = 15
if number % 3 == 0 and number % 5 == 0:
    print("Number is divisible by 3 and 5")
