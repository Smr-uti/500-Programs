# %% [markdown]
# #### 4. Discount / Free Delivery Eligibility: If the shopping bill amount is greater than 500, tell the user they got free delivery.

# %%
bill_amount=int(input("Enter the bill amount:"))
print(bill_amount)

if bill_amount>500:
    print("Congratulations: User get free delivery!")
# Out:
# 502
# User got free delivery
