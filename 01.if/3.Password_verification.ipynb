# %% [markdown]
# #### 3. Password Verification: Check if the user enters the correct secret password ("Python123").

# %%
password=input("Enter the password:")

if password=="Python123":
    print("Access Granted")
# Out:
# Access Granted
