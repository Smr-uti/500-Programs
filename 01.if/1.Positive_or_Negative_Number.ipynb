# %% [markdown]
# #### Program 1: Write a Python program that takes an integer input from the user and checks whether the number is positive or negative using an if-else statement.

# %%
print("Program Starts")
      
num=int(input("Enter any number:"))


if num<0:
    print("Number is negative:")    
else:
    print("Number is positive:")

print(num)
print("Program Ends")
# Out:
# Program Starts
# Number is positive:
# 50
# Program Ends
