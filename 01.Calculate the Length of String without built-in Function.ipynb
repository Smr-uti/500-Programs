# %% [markdown]
# ## Calculate the Length of a String​
#
# #### Problem Statement:
# ##### Write a Python function that calculates the length of a given string without using the built-in len() function.The function should iterate through each character and count them.

# %%
def calculate_sum(text):
    counter=0

    for char in text:
        counter=counter+1
    return counter

result=calculate_sum("pythonlearning.org")
print("length of string is:",result)
